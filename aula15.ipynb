# %% [markdown]
# Método Apply e ordenação de dataframes

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tested.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Age'].apply(np.sqrt)#aplica uma função a uma coluna específica.
# Out:
# 0      5.873670
# 1      6.855655
# 2      7.874008
# 3      5.196152
# 4      4.690416
#          ...
# 413         NaN
# 414    6.244998
# 415    6.204837
# 416         NaN
# 417         NaN
# Name: Age, Length: 418, dtype: float64

# %%
def changesurvived(el):
    if el == 0:
        return "No"
    else: 
        return "Yes"

df['Survived'] = df['Survived'].apply(changesurvived)
df.head()
# Out:
#    PassengerId Survived  Pclass                                          Name  \
# 0          892       No       3                              Kelly, Mr. James
# 1          893      Yes       3              Wilkes, Mrs. James (Ellen Needs)
# 2          894       No       2                     Myles, Mr. Thomas Francis
# 3          895       No       3                              Wirz, Mr. Albert
# 4          896      Yes       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
def changeFare(el):
    return "${:.2f}".format(el)
   

df['Fare'] = df['Fare'].apply(changeFare)
df.head()
# Out:
#    PassengerId Survived  Pclass                                          Name  \
# 0          892       No       3                              Kelly, Mr. James
# 1          893      Yes       3              Wilkes, Mrs. James (Ellen Needs)
# 2          894       No       2                     Myles, Mr. Thomas Francis
# 3          895       No       3                              Wirz, Mr. Albert
# 4          896      Yes       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket    Fare Cabin Embarked
# 0    male  34.5      0      0   330911   $7.83   NaN        Q
# 1  female  47.0      1      0   363272   $7.00   NaN        S
# 2    male  62.0      0      0   240276   $9.69   NaN        Q
# 3    male  27.0      0      0   315154   $8.66   NaN        S
# 4  female  22.0      1      1  3101298  $12.29   NaN        S

# %% [markdown]
# Ordenação:

# %%
df_sort = df.sort_values(by='Age', ascending=True)
df_sort.dropna()
# Out:
#      PassengerId Survived  Pclass  \
# 117         1009      Yes       3
# 196         1088       No       1
# 326         1218      Yes       2
# 64           956       No       1
# 395         1287      Yes       1
# ..           ...      ...     ...
# 179         1071      Yes       1
# 236         1128       No       1
# 305         1197      Yes       1
# 81           973       No       1
# 96           988      Yes       1
#
#                                                   Name     Sex   Age  SibSp  \
# 117                    Sandstrom, Miss. Beatrice Irene  female   1.0      1
# 196                    Spedden, Master. Robert Douglas    male   6.0      0
# 326                       Becker, Miss. Ruth Elizabeth  female  12.0      2
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  female  18.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_sort = df.sort_values(by='Age', ascending=False)
df_sort
# Out:
#      PassengerId Survived  Pclass  \
# 96           988      Yes       1
# 81           973       No       1
# 236         1128       No       1
# 179         1071      Yes       1
# 305         1197      Yes       1
# ..           ...      ...     ...
# 408         1300      Yes       3
# 410         1302      Yes       3
# 413         1305       No       3
# 416         1308       No       3
# 417         1309       No       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.random.rand(6)
plt.plot(array)
plt.grid()

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title('Seno')
plt.xlabel('X')
plt.ylabel('sen(X)')

plt.grid()
